# %%
import pandas as pd
import json
import requests
from pandas import json_normalize  # Import json_normalize

url = "https://realty-in-au.p.rapidapi.com/properties/list"

querystring = {"channel":"buy","searchLocation":"Willetton, WA 6155","searchLocationSubtext":"Region","type":"region","page":"1","pageSize":"30","sortType":"relevance","surroundingSuburbs":"true","ex-under-contract":"false"}

headers = {
    "X-RapidAPI-Key": "db5ad576ddmsh6a06fb52f495a97p161174jsnd62ba1e007f8",
    "X-RapidAPI-Host": "realty-in-au.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# Uncomment the line below if you want to print the JSON response
# jprint(response.json())

# Load the JSON data into a Pandas DataFrame
data = response.json()
tiered_results = data['tieredResults']
results = []
for tier in tiered_results:
    results.extend(tier['results'])

# Flatten the nested dictionaries in the 'generalFeatures' column
df = json_normalize(results, sep='_')
print(df)
# Out:
#                                            prettyUrl  standard  midtier
# 0              property-house-wa-willetton-142006916     False    False  \
# 1              property-house-wa-willetton-140856680     False    False
# 2              property-house-wa-willetton-139853155     False    False
# 3              property-house-wa-willetton-141529428     False    False
# 4              property-house-wa-willetton-141661784     False    False
# 5              property-house-wa-willetton-141657912     False    False
# 6              property-house-wa-willetton-141775168     False    False
# 7              property-house-wa-willetton-139831155     False    False
# 8              property-house-wa-willetton-141052984     False    False
# 9              property-house-wa-willetton-141269480     False    False
# 10             property-house-wa-willetton-141751964     False    False
# 11             property-house-wa-willetton-141866988     False    False
# 12             property-house-wa-willetton-141860104     False    False
# 13  property-residential land-wa-willetton-203522576     False    False
# 14  property-residential land-wa-willetton-203596740     False    False
# 15             property-house-wa-willetton-141950588     False    False
# 16  property-residential land-wa-willetton-203395651     False    False
# 17             property-house-wa-willetton-141729672     False    False
# 18             property-house-wa-willetton-140907796     False    False
# 19              property-unit-wa-willetton-141114548     False    False
# 20             property-house-wa-willetton-141456532     False    False
# 21             property-house-wa-willetton-141706124     False    False
# 22             property-house-wa-willetton-141710740     False    False
# 23             property-house-wa-willetton-141841460     False    False
# 24         property-apartment-wa-willetton-140399691     False    False
# 25             property-house-wa-willetton-140399267     False    False
# 26             property-house-wa-willetton-141933896     False    False
# 27             property-house-wa-willetton-140881732     False    False
# 28             property-house-wa-willetton-141697960     False    False
# 29             property-house-wa-willetton-141923540     False    False
#
#     featured  signature constructionStatus channel
# 0      False       True        established     buy  \
# 1      False       True        established     buy
# 2      False       True        established     buy
# 3      False       True        established     buy
# 4      False       True        established     buy
# 5      False       True        established     buy
# 6      False       True        established     buy
# 7      False       True        established     buy
# 8      False       True        established     buy
# 9      False       True        established     buy
# 10     False       True        established     buy
# 11     False       True        established     buy
# 12     False       True        established     buy
# 13     False       True        established     buy
# 14     False       True        established     buy
# 15     False       True        established     buy
# 16     False       True        established     buy
# 17     False       True        established     buy
# 18     False       True        established     buy
# 19     False       True        established     buy
# 20     False       True        established     buy
# 21     False       True        established     buy
# 22     False       True        established     buy
# 23     False       True        established     buy
# 24     False       True        established     buy
# 25     False       True        established     buy
# 26     False       True        established     buy
# 27     False       True        established     buy
# 28     False       True        established     buy
# 29     False       True        established     buy
#
#                                           description  showAgencyLogo
# 0   Welcome to 6 Hornet Rise Willetton! No need to...            True  \
# 1   ** UNDER OFFER BY TEAM SUTRISNO **<br/><br/>Ar...            True
# 2   We have the great pleasure to present this coz...            True
# 3   FIRST TIME EVER TO THE MARKET!! This very love...            True
# 4   Street front three-bedroom duplex, in a well-s...            True
# 5   Been looking for a family home with everything...            True
# 6   Be impressed with this spacious 5 x 2 family h...            True
# 7   Welcome to 32 Chapparral Cres, Willetton. This...            True
# 8   IdealRealtyWA is proud to present this gorgeou...            True
# 9   Standing proud in the heart of Willetton and f...            True
# 10  Looking for the perfect family home in the hig...            True
# 11  Snuggly tucked away in a quiet locale, this fu...            True
# 12  I'm sure you will fall in love with this stunn...            True
# 13  Your opportunity to get into this lovely famil...            True
# 14  Nikki Varga is delighted to present 4b Mendip ...            True
# 15  Welcome to this exceptional family home locate...            True
# 16  LOT 2 – 350SQM excluding the common driveway.<...            True
# 17  The Openn Negotiation (online auction) is unde...            True
# 18  A Blank Slate Ready To Build In The Heart Of W...            True
# 19  Don't look further than this well renovated, f...            True
# 20  This Beautiful Open plan home in a TRULY Super...            True
# 21  An amazing transformation into a luxurious fam...            True
# 22  A wonderfully renovated family home that will ...            True
# 23  Great Opportunity to move so close to Rossmoyn...            True
# 24  This attractive ground-floor apartment is tuck...            True
# 25  You don't get much better than this - a big 68...            True
# 26  Located in the heart of Willetton, this three ...            True
# 27  We have the great pleasure to present this fam...            True
# 28  Set on the elevated side of Chancery Crescent ...            True
# 29  ULTIMATE IN FAMILY LIVING! Semple Property Gro...            True
#
#                                                 title  ...
# 0             RESORT LIVING IN THE HEART OF WILLETTON  ...  \
# 1   REMARKABLE FOUR BEDROOM HOME WITH AN UPSTAIRS ...  ...
# 2   ADORABLE 4X1 FAMILY HOME IN WILLETTON SENIOR S...  ...
# 3   GREAT BUYING HUGE 838SQM BLOCK ! PLUS LARGE 3 ...  ...
# 4               Affordable Entry Point Into Willetton  ...
# 5                     LARGE FAMILY HOME IN CUL DE SAC  ...
# 6                     Big home in Willetton SHS zone.  ...
# 7   Willetton School Zone Sub-dividable huge block...  ...
# 8   BRAND NEW DOUBLE STOREY STUNNING HOME IN DUAL ...  ...
# 9                                WILLETTON'S LANDMARK  ...
# 10                    Great Investment or Family Home  ...
# 11                                 The Beauty Within!  ...
# 12     HOME OPEN CANCELLED, UNDER OFFER IN 48 HOURS !  ...
# 13                         Walking Distance to RSHZ !  ...
# 14                       It's all about the location!  ...
# 15              Gem in WSHS Zone - 3x2x2 Plus a Study  ...
# 16    TITLE ISSUED AND READY TO BUILD YOUR DREAM HOME  ...
# 17                   Another one sold by Nikki Varga!  ...
# 18                                        UNDER OFFER  ...
# 19  AMAZING VALUE IN ROSSMOYNE SHS ZONE! DON'T MIS...  ...
# 20                     LOCATION, INVESTOR, LOCATION!!  ...
# 21                   MAGNIFICENT FAMILY ENTERTAINER!!  ...
# 22  STUNNING CONVENIENT ENTERTAINER! Home Open Can...  ...
# 23  809 SQM BLOCK IN ROSSMOYNE SENIOR HIGH SCHOOL ...  ...
# 24  Superb Location ! Great value ! Rossmoyne Seni...  ...
# 25  Great Family House in Willetton Senior High Ca...  ...
# 26  NEAT FAMILY HOME CLOSE TO WILLETTON SENIOR HIG...  ...
# 27  Development Opportunity in Willetton Senior Hi...  ...
# 28                                  HOME SWEET HOME!!  ...
# 29                                       UNDER OFFER!  ...
#
#     generalFeatures_parkingSpaces_type generalFeatures_parkingSpaces_value
# 0                        parkingSpaces                                 6.0  \
# 1                        parkingSpaces                                 1.0
# 2                        parkingSpaces                                 2.0
# 3                        parkingSpaces                                 5.0
# 4                        parkingSpaces                                 1.0
# 5                        parkingSpaces                                 2.0
# 6                        parkingSpaces                                 2.0
# 7                        parkingSpaces                                 2.0
# 8                        parkingSpaces                                 2.0
# 9                        parkingSpaces                                 2.0
# 10                       parkingSpaces                                 3.0
# 11                       parkingSpaces                                 2.0
# 12                       parkingSpaces                                 2.0
# 13                                 NaN                                 NaN
# 14                                 NaN                                 NaN
# 15                       parkingSpaces                                 2.0
# 16                                 NaN                                 NaN
# 17                       parkingSpaces                                 7.0
# 18                       parkingSpaces                                 2.0
# 19                       parkingSpaces                                 1.0
# 20                       parkingSpaces                                 2.0
# 21                       parkingSpaces                                 2.0
# 22                       parkingSpaces                                 2.0
# 23                       parkingSpaces                                 2.0
# 24                       parkingSpaces                                 2.0
# 25                       parkingSpaces                                 2.0
# 26                       parkingSpaces                                 1.0
# 27                       parkingSpaces                                 1.0
# 28                       parkingSpaces                                 2.0
# 29                       parkingSpaces                                 2.0
#
#    status_label  status_type nextInspectionTime_dateDisplay
# 0           New  new_listing                            NaN  \
# 1   Under Offer  under_offer                            NaN
# 2           NaN          NaN                            NaN
# 3           NaN          NaN                            NaN
# 4   Under Offer  under_offer                            NaN
# 5   Under Offer  under_offer                            NaN
# 6   Under Offer  under_offer                            NaN
# 7           NaN          NaN                            NaN
# 8           NaN          NaN                            NaN
# 9           NaN          NaN                            NaN
# 10          NaN          NaN                            NaN
# 11  Under Offer  under_offer                            NaN
# 12  Under Offer  under_offer                            NaN
# 13  Under Offer  under_offer                            NaN
# 14          NaN          NaN                            NaN
# 15          NaN          NaN                            NaN
# 16          NaN          NaN                            NaN
# 17  Under Offer  under_offer                            NaN
# 18  Under Offer  under_offer                            NaN
# 19          NaN          NaN                            NaN
# 20          NaN          NaN                            NaN
# 21  Under Offer  under_offer                            NaN
# 22  Under Offer  under_offer                            NaN
# 23  Under Offer  under_offer                            NaN
# 24          NaN          NaN                            NaN
# 25          NaN          NaN                      Sun 7 May
# 26  Under Offer  under_offer                            NaN
# 27  Under Offer  under_offer                            NaN
# 28          NaN          NaN                            NaN
# 29  Under Offer  under_offer                            NaN
#
#    nextInspectionTime_startTimeDisplay  nextInspectionTime_endTimeDisplay
# 0                                  NaN                                NaN  \
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# 5                                  NaN                                NaN
# 6                                  NaN                                NaN
# 7                                  NaN                                NaN
# 8                                  NaN                                NaN
# 9                                  NaN                                NaN
# 10                                 NaN                                NaN
# 11                                 NaN                                NaN
# 12                                 NaN                                NaN
# 13                                 NaN                                NaN
# 14                                 NaN                                NaN
# 15                                 NaN                                NaN
# 16                                 NaN                                NaN
# 17                                 NaN                                NaN
# 18                                 NaN                                NaN
# 19                                 NaN                                NaN
# 20                                 NaN                                NaN
# 21                                 NaN                                NaN
# 22                                 NaN                                NaN
# 23                                 NaN                                NaN
# 24                                 NaN                                NaN
# 25                             1:00 PM                            1:30 PM
# 26                                 NaN                                NaN
# 27                                 NaN                                NaN
# 28                                 NaN                                NaN
# 29                                 NaN                                NaN
#
#     nextInspectionTime_startTime  nextInspectionTime_endTime
# 0                            NaN                         NaN  \
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# 5                            NaN                         NaN
# 6                            NaN                         NaN
# 7                            NaN                         NaN
# 8                            NaN                         NaN
# 9                            NaN                         NaN
# 10                           NaN                         NaN
# 11                           NaN                         NaN
# 12                           NaN                         NaN
# 13                           NaN                         NaN
# 14                           NaN                         NaN
# 15                           NaN                         NaN
# 16                           NaN                         NaN
# 17                           NaN                         NaN
# 18                           NaN                         NaN
# 19                           NaN                         NaN
# 20                           NaN                         NaN
# 21                           NaN                         NaN
# 22                           NaN                         NaN
# 23                           NaN                         NaN
# 24                           NaN                         NaN
# 25           2023-05-07T13:00:00         2023-05-07T13:30:00
# 26                           NaN                         NaN
# 27                           NaN                         NaN
# 28                           NaN                         NaN
# 29                           NaN                         NaN
#
#     nextInspectionTime_auction
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                       False
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
#
# [30 rows x 96 columns]
