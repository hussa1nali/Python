# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize  # Import json_normalize

url = "https://realty-in-au.p.rapidapi.com/properties/list"

querystring = {"channel":"buy","searchLocation":"Willetton, WA 6155","searchLocationSubtext":"Region","type":"region","page":"1","pageSize":"30","sortType":"relevance","surroundingSuburbs":"true","ex-under-contract":"false"}

headers = {
    "X-RapidAPI-Key": "db5ad576ddmsh6a06fb52f495a97p161174jsnd62ba1e007f8",
    "X-RapidAPI-Host": "realty-in-au.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# Uncomment the line below if you want to print the JSON response
# jprint(response.json())

# Load the JSON data into a Pandas DataFrame
data = response.json()
tiered_results = data['tieredResults']
results = []
for tier in tiered_results:
    results.extend(tier['results'])

# Flatten the nested dictionaries in the 'generalFeatures' column
df = json_normalize(results, sep='_')
print(df)
# Out:
#                                             prettyUrl  standard  midtier  \
# 0               property-house-wa-willetton-141775168     False    False
# 1               property-house-wa-willetton-141729672     False    False
# 2               property-house-wa-willetton-141816700     False    False
# 3               property-house-wa-willetton-139831155     False    False
# 4               property-house-wa-willetton-141052984     False    False
# 5               property-house-wa-willetton-141269480     False    False
# 6               property-house-wa-willetton-141751964     False    False
# 7               property-house-wa-willetton-141866988     False    False
# 8               property-house-wa-willetton-141860104     False    False
# 9   property-duplex+semi-detached-wa-willetton-141...     False    False
# 10   property-residential land-wa-willetton-203522576     False    False
# 11              property-house-wa-willetton-140907796     False    False
# 12               property-unit-wa-willetton-141114548     False    False
# 13              property-house-wa-willetton-141456532     False    False
# 14              property-house-wa-willetton-141706124     False    False
# 15              property-house-wa-willetton-141710740     False    False
# 16              property-house-wa-willetton-141841460     False    False
# 17          property-apartment-wa-willetton-140399691     False    False
# 18              property-house-wa-willetton-140399267     False    False
# 19              property-house-wa-willetton-141830004     False    False
# 20              property-house-wa-willetton-140881732     False    False
# 21              property-house-wa-willetton-141697960     False    False
# 22              property-house-wa-willetton-141694084     False    False
# 23              property-house-wa-willetton-140630451     False    False
# 24              property-house-wa-willetton-141693948     False    False
# 25              property-house-wa-willetton-141818492     False    False
# 26              property-house-wa-willetton-141803288     False    False
# 27              property-house-wa-willetton-141557656     False    False
# 28              property-house-wa-willetton-141554320     False    False
# 29              property-house-wa-willetton-140856680     False    False
#
#     featured  signature constructionStatus channel  \
# 0      False       True        established     buy
# 1      False       True        established     buy
# 2      False       True        established     buy
# 3      False       True        established     buy
# 4      False       True        established     buy
# 5      False       True        established     buy
# 6      False       True        established     buy
# 7      False       True        established     buy
# 8      False       True        established     buy
# 9      False       True        established     buy
# 10     False       True        established     buy
# 11     False       True        established     buy
# 12     False       True        established     buy
# 13     False       True        established     buy
# 14     False       True        established     buy
# 15     False       True        established     buy
# 16     False       True        established     buy
# 17     False       True        established     buy
# 18     False       True        established     buy
# 19     False       True        established     buy
# 20     False       True        established     buy
# 21     False       True        established     buy
# 22     False       True        established     buy
# 23     False       True        established     buy
# 24     False       True        established     buy
# 25     False       True        established     buy
# 26     False       True        established     buy
# 27     False       True        established     buy
# 28     False       True        established     buy
# 29     False       True        established     buy
#
#                                           description  showAgencyLogo  \
# 0   Be impressed with this spacious 5 x 2 family h...            True
# 1   The Openn Negotiation (online auction) is unde...            True
# 2   Nikki Varga is delighted to present to the mar...            True
# 3   Welcome to 32 Chapparral Cres, Willetton. This...            True
# 4   IdealRealtyWA is proud to present this gorgeou...            True
# 5   Standing proud in the heart of Willetton and f...            True
# 6   Looking for the perfect family home in the hig...            True
# 7   Snuggly tucked away in a quiet locale, this fu...            True
# 8   I'm sure you will fall in love with this stunn...            True
# 9   Nestled in a quiet cul-de-sac, on an elevated ...            True
# 10  Your opportunity to get into this lovely famil...            True
# 11  A Blank Slate Ready To Build In The Heart Of W...            True
# 12  Don't look further than this well renovated, f...            True
# 13  This Beautiful Open plan home in a TRULY Super...            True
# 14  An amazing transformation into a luxurious fam...            True
# 15  A wonderfully renovated family home that will ...            True
# 16  Great Opportunity to move so close to Rossmoyn...            True
# 17  This attractive ground-floor apartment is tuck...            True
# 18  You don't get much better than this - a big 68...            True
# 19  This one is not to be missed!! Cul-de-sac loca...            True
# 20  We have the great pleasure to present this fam...            True
# 21  Set on the elevated side of Chancery Crescent ...            True
# 22  “ SITE IS UNDER CONSTRUCTION AND SO ENTRY INSI...            True
# 23  This gorgeous double storey home is everything...            True
# 24  IdealRealtyWA is proud to present this prefect...            True
# 25  *** HOME OPEN CANCELLED FOR SUNDAY***<br/><br/...            True
# 26  Looking for a fantastic investment opportunity...            True
# 27  IdealRealtyWA is proud to present this large a...            True
# 28  Located in the desirable suburb of Willetton, ...            True
# 29  Are you looking for a family home or an invest...            True
#
#                                                 title  ...  \
# 0                     Big home in Willetton SHS zone.  ...
# 1                    Another one sold by Nikki Varga!  ...
# 2                    Another one sold by Nikki Varga!  ...
# 3   Willetton School Zone Sub-dividable huge block...  ...
# 4   BRAND NEW DOUBLE STOREY STUNNING HOME IN DUAL ...  ...
# 5                                WILLETTON'S LANDMARK  ...
# 6                     Great Investment or Family Home  ...
# 7                                  The Beauty Within!  ...
# 8      HOME OPEN CANCELLED, UNDER OFFER IN 48 HOURS !  ...
# 9                              Investment Opportunity  ...
# 10                         Walking Distance to RSHZ !  ...
# 11                                             OFFERS  ...
# 12  AMAZING VALUE IN ROSSMOYNE SHS ZONE! DON'T MIS...  ...
# 13                     LOCATION, INVESTOR, LOCATION!!  ...
# 14                   MAGNIFICENT FAMILY ENTERTAINER!!  ...
# 15  STUNNING CONVENIENT ENTERTAINER! Home Open Can...  ...
# 16  809 SQM BLOCK IN ROSSMOYNE SENIOR HIGH SCHOOL ...  ...
# 17  Superb Location ! Great value ! Rossmoyne Seni...  ...
# 18  Great Family House within Willetton Senior Hig...  ...
# 19     SPACIOUS FAMILY HOME - FLEXIBLE LIVING OPTIONS  ...
# 20  Development Opportunity in Willetton Senior Hi...  ...
# 21                                  HOME SWEET HOME!!  ...
# 22    BRAND NEW DOUBLE STOREY HOME IN RSHZ - HIGH END  ...
# 23           BRAND NEW HOME IN WSHZ AND READY ON 2023  ...
# 24        PERFECT FAMILY HOME ON CORNER BLOCK IN WSHZ  ...
# 25       UNDER OFFER AFTER FIRST HOME OPEN 0409209899  ...
# 26     Subdividable R40 (STCA) Block in TOP LOCATION.  ...
# 27                            A GORGEOUS FAMILY ABODE  ...
# 28            5 OFFERS!! NEED HOUSE NEARBY URGENTLY!!  ...
# 29  REMARKABLE FOUR BEDROOM HOME WITH AN UPSTAIRS ...  ...
#
#     generalFeatures_parkingSpaces_type generalFeatures_parkingSpaces_value  \
# 0                        parkingSpaces                                 2.0
# 1                        parkingSpaces                                 7.0
# 2                        parkingSpaces                                 2.0
# 3                        parkingSpaces                                 2.0
# 4                        parkingSpaces                                 2.0
# 5                        parkingSpaces                                 2.0
# 6                        parkingSpaces                                 3.0
# 7                        parkingSpaces                                 2.0
# 8                        parkingSpaces                                 2.0
# 9                        parkingSpaces                                 3.0
# 10                                 NaN                                 NaN
# 11                       parkingSpaces                                 2.0
# 12                       parkingSpaces                                 1.0
# 13                       parkingSpaces                                 2.0
# 14                       parkingSpaces                                 2.0
# 15                       parkingSpaces                                 2.0
# 16                       parkingSpaces                                 2.0
# 17                       parkingSpaces                                 2.0
# 18                       parkingSpaces                                 2.0
# 19                       parkingSpaces                                 4.0
# 20                       parkingSpaces                                 1.0
# 21                       parkingSpaces                                 2.0
# 22                       parkingSpaces                                 2.0
# 23                       parkingSpaces                                 2.0
# 24                       parkingSpaces                                 4.0
# 25                       parkingSpaces                                 7.0
# 26                       parkingSpaces                                 1.0
# 27                       parkingSpaces                                 4.0
# 28                       parkingSpaces                                 2.0
# 29                       parkingSpaces                                 1.0
#
#    status_label  status_type nextInspectionTime_dateDisplay  \
# 0           NaN          NaN                            NaN
# 1           NaN          NaN                            NaN
# 2   Under Offer  under_offer                            NaN
# 3           NaN          NaN                            NaN
# 4           NaN          NaN                       Tomorrow
# 5           NaN          NaN                            NaN
# 6           NaN          NaN                            NaN
# 7           New  new_listing                       Tomorrow
# 8   Under Offer  under_offer                            NaN
# 9   Under Offer  under_offer                            NaN
# 10  Under Offer  under_offer                            NaN
# 11          NaN          NaN                       Tomorrow
# 12          NaN          NaN                       Tomorrow
# 13          NaN          NaN                            NaN
# 14  Under Offer  under_offer                            NaN
# 15  Under Offer  under_offer                            NaN
# 16  Under Offer  under_offer                            NaN
# 17          NaN          NaN                            NaN
# 18          NaN          NaN                     Sun 16 Apr
# 19  Under Offer  under_offer                            NaN
# 20  Under Offer  under_offer                            NaN
# 21          NaN          NaN                            NaN
# 22          NaN          NaN                       Tomorrow
# 23          NaN          NaN                            NaN
# 24          NaN          NaN                            NaN
# 25  Under Offer  under_offer                            NaN
# 26          NaN          NaN                       Tomorrow
# 27          NaN          NaN                       Tomorrow
# 28  Under Offer  under_offer                            NaN
# 29          NaN          NaN                            NaN
#
#    nextInspectionTime_startTimeDisplay  nextInspectionTime_endTimeDisplay  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                              2:00 PM                            2:30 PM
# 5                                  NaN                                NaN
# 6                                  NaN                                NaN
# 7                             11:00 AM                           11:45 AM
# 8                                  NaN                                NaN
# 9                                  NaN                                NaN
# 10                                 NaN                                NaN
# 11                             3:30 PM                            4:00 PM
# 12                             1:30 PM                            2:00 PM
# 13                                 NaN                                NaN
# 14                                 NaN                                NaN
# 15                                 NaN                                NaN
# 16                                 NaN                                NaN
# 17                                 NaN                                NaN
# 18                             1:00 PM                            1:30 PM
# 19                                 NaN                                NaN
# 20                                 NaN                                NaN
# 21                                 NaN                                NaN
# 22                             1:00 PM                            1:30 PM
# 23                                 NaN                                NaN
# 24                                 NaN                                NaN
# 25                                 NaN                                NaN
# 26                            12:00 PM                           12:30 PM
# 27                             1:00 PM                            1:30 PM
# 28                                 NaN                                NaN
# 29                                 NaN                                NaN
#
#     nextInspectionTime_startTime  nextInspectionTime_endTime  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4            2023-04-08T14:00:00         2023-04-08T14:30:00
# 5                            NaN                         NaN
# 6                            NaN                         NaN
# 7            2023-04-08T11:00:00         2023-04-08T11:45:00
# 8                            NaN                         NaN
# 9                            NaN                         NaN
# 10                           NaN                         NaN
# 11           2023-04-08T15:30:00         2023-04-08T16:00:00
# 12           2023-04-08T13:30:00         2023-04-08T14:00:00
# 13                           NaN                         NaN
# 14                           NaN                         NaN
# 15                           NaN                         NaN
# 16                           NaN                         NaN
# 17                           NaN                         NaN
# 18           2023-04-16T13:00:00         2023-04-16T13:30:00
# 19                           NaN                         NaN
# 20                           NaN                         NaN
# 21                           NaN                         NaN
# 22           2023-04-08T13:00:00         2023-04-08T13:30:00
# 23                           NaN                         NaN
# 24                           NaN                         NaN
# 25                           NaN                         NaN
# 26           2023-04-08T12:00:00         2023-04-08T12:30:00
# 27           2023-04-08T13:00:00         2023-04-08T13:30:00
# 28                           NaN                         NaN
# 29                           NaN                         NaN
#
#     nextInspectionTime_auction
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                        False
# 5                          NaN
# 6                          NaN
# 7                        False
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                       False
# 12                       False
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                       False
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                       False
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                       False
# 27                       False
# 28                         NaN
# 29                         NaN
#
# [30 rows x 96 columns]
# C:\Users\hussa\AppData\Local\Temp\ipykernel_11980\750527917.py:32: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(results, sep='_')
